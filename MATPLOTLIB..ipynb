# %%
# !pip install matplotlib seabron --upgrade --quiet
# Out:
# ERROR: Could not find a version that satisfies the requirement seabron (from versions: none)
# ERROR: No matching distribution found for seabron

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
yield_apples = [.895, .91, .919, .926, .929, .931]

# %%
plt.plot(yield_apples)

# %%
years = [2010, 2011, 2012, 2013, 2014, 2015]
plt.plot(years, yield_apples)

# %%
plt.plot(years, yield_apples)
plt.xlabel('year')
plt.ylabel('Yield (tons per hectare)');

# %%
years = range(2000, 2012)
apples = [.895, .91, .919, .926, .929, .931, .934, .936, .937, .9375, .9372, .939]
oranges = [.962, .941, .930, .923, .918, .908, .907, .904, .901, .898, .9, .896]

# %%
plt.plot(years, apples, marker='o')
plt.plot(years, oranges, marker='x')

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges']);

# %%
years=range(2000,2012)
apples=[.895,.918,.919,.926,.929,.931,.932,.933,.934,.935,.936,.937]
orange=[.962,.941,.930,.923,.918,.908,.909,.910,.911,.912,.913,.914]

# %%
plt.plot(years,apples,marker='o')
plt.plot(years,orange,marker='x')
plt.xlabel('Year')
plt.ylabel('yield')
plt.title("crop yield in kanto")
plt.legend(['Apples','Orange']);

# %%
plt.plot(years, apples, marker='s', c='b', ls='-', lw=2, ms=8, mew=2, mec='navy')
plt.plot(years, oranges, marker='o', c='r', ls='--', lw=3, ms=10, alpha=0.3)
plt.xlabel('Year')
plt.ylabel('yield')
plt.title("crop yield in kanto")
plt.legend(['Apples','Orange']);

# %%
plt.plot(years, apples, 's-b')
plt.plot(years, oranges, 'o--r')
plt.xlabel('Year')
plt.ylabel('yield')
plt.title("crop yield in kanto")
plt.legend(['Apples','Orange']);

# %%
plt.figure(figsize=(12, 6))
plt.plot(years, oranges, 'or')
plt.title("Yield of Oranges (tons per hectare)");

# %%
sns.set_style("whitegrid")

# %%
import seaborn as sns

# %%
sns.set_style("whitegrid")

# %%
plt.plot(years, apples, 's-b')
plt.plot(years, oranges, 'o--r')
plt.xlabel('Year')
plt.ylabel('yield')
plt.title("crop yield in kanto")
plt.legend(['Apples','Orange']);

# %%
import matplotlib
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# Scatter plot

# %%
flowers_df = sns.load_dataset("iris")
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.plot(flowers_df.sepal_length, flowers_df.sepal_width);

# %%
sns.scatterplot(x=flowers_df.sepal_length, y=flowers_df.sepal_width)
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x=flowers_df.sepal_length, y=flowers_df.sepal_width, hue=flowers_df.species, s=50);

# %%
plt.figure(figsize=(12, 6))
plt.title('Sepal Dimentions')
sns.scatterplot(x=flowers_df.sepal_length, y=flowers_df.sepal_width, hue=flowers_df.species, s=50);

# %% [markdown]
# Histogram

# %%
plt.title("Distribution of Sepal Width")
plt.hist(flowers_df.sepal_width);

# %%
plt.hist(flowers_df.sepal_width, bins=10);

# %%
import numpy as np

# %%
plt.hist(flowers_df.sepal_width, bins=np.arange(2,5,0.25));

# %%
plt.hist(flowers_df.sepal_width, bins=[1,3,4,4.5]);

# %%
setosa_df = flowers_df[flowers_df.species == 'setosa']
versicolor_df = flowers_df[flowers_df.species == 'vericolor']
virginica_df = flowers_df[flowers_df.species == 'virginica']

# %%
plt.hist(setosa_df.sepal_width, alpha=0.4, bins=np.arange(2,5,0.25));
plt.hist(versicolor_df.sepal_width, alpha=0.4, bins=np.arange(2,5,0.25));

# %%
plt.title('Distrbution of sepal width')
plt.hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width],bins=np.arange(2,5,0.25),stacked=True);
plt.legend(['Setosa', 'Versicolor', 'Virginica']);
